# %%
install.packages("datasets")


library(datasets)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘datasets’ is a base package, and should not be updated”

# %%
df<-iris

# %%
head(df,5)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa

# %%
options(repr.plot.width = 15, repr.plot.height = 8)

# %%
hist(df$Sepal.Length,main="Iris Sepal Length",xlab="Sepal Length",col="blue",breaks=30)
# Out:
# Plot with title “Iris Sepal Length”

# %%
x<-15
x
# Out:
# [1] 15

# %%
typeof(x)
# Out:
# [1] "double"

# %%
x1<-1.5
typeof(x1)
# Out:
# [1] "double"

# %%
c="x"
typeof(c)
# Out:
# [1] "character"

# %%
l=TRUE
typeof(l)
# Out:
# [1] "logical"

# %%
l2=F
typeof(l2)
# Out:
# [1] "logical"

# %%
v<-c(1,2,3,4,5,6)
is.vector(v)
# Out:
# [1] TRUE

# %%
v1<-c("1","a","b","c","d")
is.vector(v1)
# Out:
# [1] TRUE

# %%
v3 <- c(TRUE, TRUE, FALSE, FALSE, TRUE)
is.vector(v3)
# Out:
# [1] TRUE

# %%
m<-matrix(c(1,2,3,4,5,6),nrow=2,ncol=3)
m
# Out:
#      [,1] [,2] [,3]
# [1,] 1    3    5
# [2,] 2    4    6

# %%
typeof(m)
# Out:
# [1] "double"

# %%
m1<-matrix(c("a","b","c","d"),nrow=2,byrow=T)
m1
# Out:
#      [,1] [,2]
# [1,] a    b
# [2,] c    d

# %%
# Multi-dimensional set of same data type;
# columns must be same length (no missing data)

# Give data, then dimensions (rows, columns, tables)
a1 <- array(c( 1:24), c(4, 3, 2))
a1[,,1]
# Out:
#      [,1] [,2] [,3]
# [1,] 1    5     9
# [2,] 2    6    10
# [3,] 3    7    11
# [4,] 4    8    12

# %%
a1[,,2]
# Out:
#      [,1] [,2] [,3]
# [1,] 13   17   21
# [2,] 14   18   22
# [3,] 15   19   23
# [4,] 16   20   24

# %%
vNumeric   <- c(1, 2, 3)
vCharacter <- c("a", "b", "c")
vLogical   <- c(T, F, T)

# %%
df1 <- cbind(vNumeric, vCharacter, vLogical)
df1  # Coerces all values to most basic data type
# Out:
#      vNumeric vCharacter vLogical
# [1,] 1        a          TRUE
# [2,] 2        b          FALSE
# [3,] 3        c          TRUE

# %%
df2 <- data.frame(vNumeric, vCharacter, vLogical)
df2  # Makes a data frame with three different data types
# Out:
#   vNumeric vCharacter vLogical
# 1 1        a           TRUE
# 2 2        b          FALSE
# 3 3        c           TRUE

# %%
o1 <- c(1, 2, 3)
o2 <- c("a", "b", "c", "d")
o3 <- c(T, F, T, T, F)

# %%
list1 <- list(o1, o2, o3)
list1
# Out:
# [[1]]
# [1] 1 2 3
#
# [[2]]
# [1] "a" "b" "c" "d"
#
# [[3]]
# [1]  TRUE FALSE  TRUE  TRUE FALSE

# %%
list2 <- list(o1, o2, o3, list1)  # Lists within lists!
list2
# Out:
# [[1]]
# [1] 1 2 3
#
# [[2]]
# [1] "a" "b" "c" "d"
#
# [[3]]
# [1]  TRUE FALSE  TRUE  TRUE FALSE
#
# [[4]]
# [[4]][[1]]
# [1] 1 2 3
#
# [[4]][[2]]
# [1] "a" "b" "c" "d"
#
# [[4]][[3]]
# [1]  TRUE FALSE  TRUE  TRUE FALSE

# %%
(coerce1 <- c(1, "b", TRUE))
typeof(coerce1)
# Out:
# [1] "1"    "b"    "TRUE"
# [1] "character"

# %%
(coerce2 <- 5)
typeof(coerce2)

(coerce3 <- as.integer(5))
typeof(coerce3)
# Out:
# [1] 5
# [1] "double"
# [1] 5
# [1] "integer"

# %%
(coerce4 <- c("1", "2", "3"))
typeof(coerce4)

(coerce5 <- as.numeric(c("1", "2", "3")))
typeof(coerce5)
# Out:
# [1] "1" "2" "3"
# [1] "character"
# [1] 1 2 3
# [1] "double"

# %%
(coerce6 <- matrix(1:9, nrow= 3))
is.matrix(coerce6)

(coerce7 <- as.data.frame(matrix(1:9, nrow= 3)))
is.data.frame(coerce7)
# Out:
#      [,1] [,2] [,3]
# [1,] 1    4    7
# [2,] 2    5    8
# [3,] 3    6    9
# [1] TRUE
#   V1 V2 V3
# 1 1  4  7
# 2 2  5  8
# 3 3  6  9
# [1] TRUE

# %%
x=c(10,20,30,40,50,60,70)
barplot(x)
# Out:
# plot without title

# %%
browseURL("https://datalab.cc/rcolors")

# %%
barplot(x,col="red3")
barplot(x,col="slategray3")
# Out:
# plot without title
# plot without title

# %%
# RGB triplets (0-255)
barplot(x, col = rgb(205, 0, 0, max = 255))     # red3
barplot(x, col = rgb(159, 182, 205, max = 255)) # slategray3
# Out:
# plot without title
# plot without title

# %%
# RGB hexcodes
barplot(x, col = "#CD0000")  # red3
barplot(x, col = "#9FB6CD")  # slategray3
# Out:
# plot without title
# plot without title

# %%
# Index numbers
barplot(x, col = colors() [555])  # red3
barplot(x, col = colors() [602])  # slategray3
# Out:
# plot without title
# plot without title

# %%
barplot(x, col = 1:6)
# Out:
# plot without title

# %%
barplot(x, col = rainbow(6))         # Rainbow colors
barplot(x, col = heat.colors(6))     # Yellow through
# Out:
# plot without title
# plot without title

# %%
barplot(x, col = terrain.colors(6))  # Gray through
# Out:
# plot without title

# %%
barplot(x, col = topo.colors(6))     # Purple through
# Out:
# plot without title

# %%
barplot(x, col = cm.colors(6))
# Out:
# plot without title

# %%
install.packages("tidyverse")
install.packages("readxl")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
library(readxl)

# %%
df<-read.csv("/content/state_trends.csv") |> mutate(across(c(region:psy_reg),factor)) |>print()
# Out:
#             state state_code population sq_miles pop_density    region
# 1         Alabama         AL    5024279    52420          96     South
# 2         Arizona         AZ    7151502   113990          63      West
# 3        Arkansas         AR    3011524    53179          57     South
# 4      California         CA   39538223   163695         242      West
# 5        Colorado         CO    5773714   104094          55      West
# 6     Connecticut         CT    3605944     5543         650 Northeast
# 7        Delaware         DE     989948     2489         398     South
# 8         Florida         FL   21538187    65758         328     South
# 9         Georgia         GA   10711908    59425         180     South
# 10          Idaho         ID    1839106    83569          22      West
# 11       Illinois         IL   12812508    57914         221   Midwest
# 12        Indiana         IN    6785528    36420         186   Midwest
# 13           Iowa         IA    3190369    56273          57   Midwest
# 14         Kansas         KS    2937880    82278          36   Midwest
# 15       Kentucky         KY    4505836    40408         112     South
# 16      Louisiana         LA    4657757    52378          89     South
# 17          Maine         ME    1362359    35380          39 Northeast
# 18       Maryland         MD    6177224    12406         498     South
# 19  Massachusetts         MA    7029917    10554         666 Northeast
# 20       Michigan         MI   10077331    96714         104   Midwest
# 21      Minnesota         MN    5706494    86936          66   Midwest
# 22    Mississippi         MS    2961279    48432          61     South
# 23       Missouri         MO    6154913    69707          88   Midwest
# 24        Montana         MT    1084225   147040           7      West
# 25       Nebraska         NE    1961504    77348          25   Midwest
# 26         Nevada         NV    3104614   110572          28      West
# 27  New Hampshire         NH    1377529     9349         147 Northeast
# 28     New Jersey         NJ    9288994     8723        1065 Northeast
# 29     New Mexico         NM    2117522   121590          17      West
# 30       New York         NY   20201249    54555         370 Northeast
# 31 North Carolina         NC   10439388    53819         194     South
# 32   North Dakota         ND     779094    70698          11   Midwest
# 33           Ohio         OH   11799448    44826         263   Midwest
# 34       Oklahoma         OK    3959353    69899          57     South
# 35         Oregon         OR    4237256    98379          43      West
# 36   Pennsylvania         PA   13002700    46054         282 Northeast
# 37   Rhode Island         RI    1097379     1545         710 Northeast
# 38 South Carolina         SC    5118425    32020         160     South
# 39   South Dakota         SD     886667    77116          11   Midwest
# 40      Tennessee         TN    6910840    42144         164     South
# 41          Texas         TX   29145505   268596         109     South
# 42           Utah         UT    3271616    84897          39      West
# 43        Vermont         VT     643077     9616          67 Northeast
# 44       Virginia         VA    8631393    42775         202     South
# 45     Washington         WA    7705281    71298         108      West
# 46  West Virginia         WV    1793716    24230          74     South
# 47      Wisconsin         WI    5893718    65496          90   Midwest
# 48        Wyoming         WY     576851    97813           6      West
#                     psych_region     psy_reg extraversion agreeableness
# 1      Friendly and Conventional    Friendly         55.5          52.7
# 2           Relaxed and Creative    Creative         50.6          46.6
# 3      Friendly and Conventional    Friendly         49.9          52.7
# 4           Relaxed and Creative    Creative         51.4          49.0
# 5      Friendly and Conventional    Friendly         45.3          47.5
# 6  Temperamental and Uninhibited Uninhibited         57.6          38.6
# 7  Temperamental and Uninhibited Uninhibited         47.0          38.8
# 8      Friendly and Conventional    Friendly         60.9          50.7
# 9      Friendly and Conventional    Friendly         63.2          60.0
# 10          Relaxed and Creative    Creative         40.7          52.9
# 11     Friendly and Conventional    Friendly         62.5          48.3
# 12     Friendly and Conventional    Friendly         48.9          50.2
# 13     Friendly and Conventional    Friendly         62.8          56.6
# 14     Friendly and Conventional    Friendly         45.5          48.9
# 15     Friendly and Conventional    Friendly         53.4          48.1
# 16     Friendly and Conventional    Friendly         52.2          49.7
# 17 Temperamental and Uninhibited Uninhibited         44.2          32.8
# 18 Temperamental and Uninhibited Uninhibited         35.2          37.3
# 19 Temperamental and Uninhibited Uninhibited         44.4          40.7
# 20     Friendly and Conventional    Friendly         55.2          54.7
# 21     Friendly and Conventional    Friendly         52.9          61.6
# 22     Friendly and Conventional    Friendly         56.8          63.3
# 23     Friendly and Conventional    Friendly         62.9          59.3
# 24     Friendly and Conventional    Friendly         33.1          52.3
# 25     Friendly and Conventional    Friendly         60.0          62.9
# 26          Relaxed and Creative    Creative         46.4          31.8
# 27 Temperamental and Uninhibited Uninhibited         40.2          53.5
# 28 Temperamental and Uninhibited Uninhibited         59.9          44.6
# 29          Relaxed and Creative    Creative         32.4          45.4
# 30 Temperamental and Uninhibited Uninhibited         47.0          29.8
# 31          Relaxed and Creative    Creative         51.0          63.6
# 32     Friendly and Conventional    Friendly         52.4          52.4
# 33 Temperamental and Uninhibited Uninhibited         54.6          45.9
# 34     Friendly and Conventional    Friendly         39.7          54.3
# 35          Relaxed and Creative    Creative         30.9          59.1
# 36 Temperamental and Uninhibited Uninhibited         54.6          42.8
# 37 Temperamental and Uninhibited Uninhibited         43.3          35.2
# 38     Friendly and Conventional    Friendly         60.0          55.4
# 39     Friendly and Conventional    Friendly         58.7          56.7
# 40     Friendly and Conventional    Friendly         51.3          66.6
# 41 Temperamental and Uninhibited Uninhibited         55.2          52.3
# 42          Relaxed and Creative    Creative         55.8          69.4
# 43 Temperamental and Uninhibited Uninhibited         26.5          60.0
# 44          Relaxed and Creative    Creative         48.5          47.4
# 45          Relaxed and Creative    Creative         30.6          55.8
# 46 Temperamental and Uninhibited Uninhibited         38.5          51.8
# 47     Friendly and Conventional    Friendly         69.8          57.8
# 48     Friendly and Conventional    Friendly         46.0          40.7
#    conscientiousness neuroticism openness data_science artificial_intelligence
# 1               55.5        48.7     42.7           20                      23
# 2               58.4        38.1     54.7           26                      26
# 3               41.0        56.2     40.3           25                      23
# 4               43.2        39.1     65.0           57                      40
# 5               58.8        34.3     57.9           37                      26
# 6               34.2        53.4     53.9           38                      32
# 7               36.5        62.4     42.7           36                      33
# 8               62.7        40.8     61.0           28                      29
# 9               68.8        38.0     56.9           34                      29
# 10              44.5        44.2     44.7           22                      25
# 11              50.9        51.2     55.2           46                      30
# 12              56.2        59.3     44.9           30                      24
# 13              52.2        49.1     33.7           25                      22
# 14              50.8        49.0     40.1           24                      26
# 15              51.3        62.5     43.0           19                      23
# 16              45.0        60.4     53.7           18                      24
# 17              24.0        71.0     50.8           20                      23
# 18              37.5        49.4     56.6           51                      43
# 19              32.2        63.8     59.6           74                      45
# 20              53.0        48.6     43.4           32                      26
# 21              52.5        43.4     38.5           35                      25
# 22              59.7        52.0     46.2           20                      27
# 23              60.8        48.3     45.7           26                      24
# 24              56.1        43.0     55.0           22                      18
# 25              64.3        41.6     34.3           22                      22
# 26              55.8        44.0     61.3           19                      26
# 27              38.0        61.8     48.7           30                      27
# 28              40.8        56.4     57.6           56                      42
# 29              58.5        51.6     62.0           20                      23
# 30              37.7        62.7     64.5           67                      56
# 31              68.4        44.8     49.6           39                      29
# 32              51.4        49.6     21.8           17                      25
# 33              46.5        58.5     46.0           25                      27
# 34              54.7        52.1     42.2           22                      21
# 35              45.8        39.5     58.8           28                      27
# 36              52.4        61.4     49.6           37                      31
# 37              48.5        61.9     59.4           44                      33
# 38              69.6        45.7     55.3           19                      25
# 39              55.8        36.1     41.9           24                      20
# 40              62.0        49.0     50.1           22                      21
# 41              54.4        44.3     52.7           37                      30
# 42              54.5        30.4     47.7           30                      26
# 43              38.2        55.8     54.2           31                      25
# 44              45.3        44.7     57.1           55                      44
# 45              45.0        36.9     56.6           51                      33
# 46              42.6        79.2     36.8           17                      20
# 47              47.6        48.6     35.7           24                      22
# 48              42.4        46.1     42.4           17                      20
#    machine_learning data_analysis business_intelligence spreadsheet statistics
# 1                23            35                    36          66         46
# 2                34            35                    50          66         53
# 3                22            40                    58          63         50
# 4                80            46                    57          77         62
# 5                41            35                    64          82         62
# 6                45            40                    53          68         65
# 7                42            43                    46          63         72
# 8                26            35                    50          58         54
# 9                38            38                    59          65         49
# 10               25            33                    54          61         66
# 11               46            40                    77          69         53
# 12               37            35                    48          59         56
# 13               31            38                    66          80         58
# 14               26            38                    65          79         62
# 15               20            31                    49          62         53
# 16               20            29                    29          64         41
# 17               19            30                    34          67         56
# 18               61            64                    59          73         66
# 19              100            62                    67          77         73
# 20               34            36                    55          66         54
# 21               35            33                    82          85         57
# 22               20            33                    27          53         46
# 23               28            31                    56          71         54
# 24               20            29                    34          72         57
# 25               22            35                    45          66         55
# 26               23            27                    33          63         44
# 27               40            38                    47          73         57
# 28               61            48                    68          63         55
# 29               33            33                    26          52         55
# 30               83            63                    67          76         62
# 31               39            40                    54          72         56
# 32               22            35                    51          78         54
# 33               29            35                    50          70         54
# 34               20            29                    41          72         49
# 35               35            31                    62          83         57
# 36               47            38                    53          65         63
# 37               48            45                    47          67         63
# 38               20            32                    43          63         52
# 39               19            31                    45          76         52
# 40               23            28                    52          59         47
# 41               42            40                    68          78         50
# 42               35            38                    54          88         61
# 43               30            35                    37          84         67
# 44               68            56                    81          82         65
# 45               73            41                   100          75         55
# 46               19            30                    24          49         55
# 47               24            29                    59          71         53
# 48               19            29                    24          61         53
#    art dance museum basketball football baseball soccer hockey has_nba has_nfl
# 1   65    65     19         55      100       58     46      7      No      No
# 2   78    69     26         33       33       37     61     12     Yes     Yes
# 3   72    61     20         61       52       89     41      4      No      No
# 4   84    70     25         21       20       33     83      8     Yes      No
# 5   85    78     29         31       33       31     71     22     Yes     Yes
# 6   80    74     31         45       23       39     91     34      No      No
# 7   72    70     26         35       34       37     65     18      No      No
# 8   77    69     24         26       37       35     70     11     Yes     Yes
# 9   71    69     21         35       61       38     62      6     Yes     Yes
# 10  82    77     17         35       41       28     65     11      No      No
# 11  74    78     32         45       30       41     74     18     Yes     Yes
# 12  74    68     26         74       40       40     65     11     Yes     Yes
# 13  69    74     21         88       77       51     67     14      No      No
# 14  80    70     26         81       47       47     80      8      No      No
# 15  71    65     24        100       47       39     58      7      No      No
# 16  68    73     27         32       51       63     44      4     Yes     Yes
# 17  85    70     34         27       21       30     60     36      No      No
# 18  76    73     33         38       30       31     87     13      No     Yes
# 19  78    76     40         27       24       37     96     52     Yes     Yes
# 20  89    70     21         53       56       31     64     30     Yes     Yes
# 21  78    77     23         40       38       42     76    100     Yes     Yes
# 22  68    63     21         46       75      100     44      5      No      No
# 23  80    75     28         41       33       50     74     20      No     Yes
# 24  78    59     26         41       42       28     47     18      No      No
# 25  70    74     27         73       90       68     80     19      No      No
# 26  74    68     33         33       27       34     67     19      No     Yes
# 27  75    81     27         24       23       33     69     46      No      No
# 28  74    74     24         33       26       38    100     20      No     Yes
# 29  86    65     33         38       29       29     62      7      No      No
# 30  80    69     41         31       19       32     79     22     Yes     Yes
# 31  73    71     25         60       44       47     70     11     Yes     Yes
# 32  73    66     14         46       48       37     48     88      No      No
# 33  75    68     25         44       54       39     69     15     Yes     Yes
# 34  72    64     26         41       63       46     61      6     Yes      No
# 35 100    75     23         33       35       36     68      7     Yes      No
# 36  72    69     27         37       41       41     80     25     Yes     Yes
# 37  78    74     33         39       21       34     75     32      No      No
# 38  72    69     20         41       67       52     58      8      No      No
# 39  70    67     23         59       50       43     54     25      No      No
# 40  67    65     26         56       61       49     61      9     Yes     Yes
# 41  74    67     21         29       40       41     71      7     Yes     Yes
# 42  89   100     23         33       44       29     83     11     Yes      No
# 43  92    79     36         32       19       30     76     48      No      No
# 44  74    74     34         43       39       36     80     13      No      No
# 45  85    66     28         29       28       27     67     11      No     Yes
# 46  66    65     16         75       61       41     55      8      No      No
# 47  81    72     28         51       38       42     61     29     Yes     Yes
# 48  78    65     29         37       43       27     47     19      No      No
#    has_mlb has_mls has_nhl has_any
# 1       No      No      No      No
# 2      Yes      No     Yes     Yes
# 3       No      No      No      No
# 4      Yes     Yes     Yes     Yes
# 5      Yes     Yes     Yes     Yes
# 6       No      No      No      No
# 7       No      No      No      No
# 8      Yes     Yes     Yes     Yes
# 9      Yes     Yes      No     Yes
# 10      No      No      No      No
# 11     Yes     Yes     Yes     Yes
# 12      No      No      No     Yes
# 13      No      No      No      No
# 14      No     Yes      No     Yes
# 15      No      No      No      No
# 16      No      No      No     Yes
# 17      No      No      No      No
# 18     Yes      No      No     Yes
# 19     Yes     Yes     Yes     Yes
# 20     Yes      No     Yes     Yes
# 21     Yes     Yes     Yes     Yes
# 22      No      No      No      No
# 23     Yes      No     Yes     Yes
# 24      No      No      No      No
# 25      No      No      No      No
# 26      No      No     Yes     Yes
# 27      No      No      No      No
# 28      No     Yes     Yes     Yes
# 29      No      No      No      No
# 30     Yes     Yes     Yes     Yes
# 31      No      No     Yes     Yes
# 32      No      No      No      No
# 33     Yes     Yes     Yes     Yes
# 34      No      No      No     Yes
# 35      No     Yes      No     Yes
# 36     Yes     Yes     Yes     Yes
# 37      No      No      No      No
# 38      No      No      No      No
# 39      No      No      No      No
# 40      No     Yes     Yes     Yes
# 41     Yes     Yes     Yes     Yes
# 42      No     Yes      No     Yes
# 43      No      No      No      No
# 44      No      No      No      No
# 45     Yes     Yes     Yes     Yes
# 46      No      No      No      No
# 47     Yes      No      No     Yes
# 48      No      No      No      No

# %%
head(df,5)
# Out:
#   state      state_code population sq_miles pop_density region
# 1 Alabama    AL          5024279    52420    96         South
# 2 Arizona    AZ          7151502   113990    63         West
# 3 Arkansas   AR          3011524    53179    57         South
# 4 California CA         39538223   163695   242         West
# 5 Colorado   CO          5773714   104094    55         West
#   psych_region              psy_reg  extraversion agreeableness ⋯ football
# 1 Friendly and Conventional Friendly 55.5         52.7          ⋯ 100
# 2 Relaxed and Creative      Creative 50.6         46.6          ⋯  33
# 3 Friendly and Conventional Friendly 49.9         52.7          ⋯  52
# 4 Relaxed and Creative      Creative 51.4         49.0          ⋯  20
# 5 Friendly and Conventional Friendly 45.3         47.5          ⋯  33
#   baseball soccer hockey has_nba has_nfl has_mlb has_mls has_nhl has_any
# 1 58       46      7     No      No      No      No      No      No
# 2 37       61     12     Yes     Yes     Yes     No      Yes     Yes
# 3 89       41      4     No      No      No      No      No      No
# 4 33       83      8     Yes     No      Yes     Yes     Yes     Yes
# 5 31       71     22     Yes     Yes     Yes     Yes     Yes     Yes

# %%
plot(df$psy_reg)
# Out:
# plot without title

# %%
# Similar process using pipes
df |>select(psy_reg) |>plot()
# Out:
# plot without title

# %%
df |> select(psy_reg) |> table() |> barplot()
# Out:
# plot without title

# %%
# Add options to plot
df |>
  select(psy_reg) |>
  table() |>  # Put data in appropriate format
  sort(decreasing = F) |>  # Sort table
  barplot(
    main   = "Personalities of 48 Contiguous US States",
    sub    = "(Source: state_trends.csv)",
    horiz  = T,  # Draw horizontal bars
    ylab   = "Personality Profile",
    xlab   = "Number of States",
    xlim   = c(0, 25),  # Limits for X axis
    border = NA,  # No borders on bars
    col    = "#CD0000"  # red3
  )
# Out:
# Plot with title “Personalities of 48 Contiguous US States”

# %%
# 100% stacked bar
df |>select(region, psy_reg) |>plot()
# Out:
# Plot with title “”

# %%
df_t<-df|>select(psy_reg,region)|>table()|>print()
# Out:
#              region
# psy_reg       Midwest Northeast South West
#   Creative          0         0     2    8
#   Friendly         11         0    10    3
#   Uninhibited       1         9     4    0

# %%
# 100% stacked bar
df |>
  select(region, psy_reg) |>
  plot()
# Out:
# Plot with title “”

# %%
# Stacked bars: step 2b: create graph w/o legend
df_t |> barplot()
# Out:
# plot without title

# %%
# Side-by-side bar w/legend
df_t |>barplot(legend = rownames(df_t),
    beside = T  # Put bars next to each other
  )
# Out:
# plot without title

# %%
# Side-by-side bar w/o legend
df_t |> barplot(beside = T)
# Out:
# plot without title

# %%
df<-read.csv("/content/state_trends.csv")

# %%
head(df,5)
# Out:
#   state      state_code population sq_miles pop_density region
# 1 Alabama    AL          5024279    52420    96         South
# 2 Arizona    AZ          7151502   113990    63         West
# 3 Arkansas   AR          3011524    53179    57         South
# 4 California CA         39538223   163695   242         West
# 5 Colorado   CO          5773714   104094    55         West
#   psych_region              psy_reg  extraversion agreeableness ⋯ football
# 1 Friendly and Conventional Friendly 55.5         52.7          ⋯ 100
# 2 Relaxed and Creative      Creative 50.6         46.6          ⋯  33
# 3 Friendly and Conventional Friendly 49.9         52.7          ⋯  52
# 4 Relaxed and Creative      Creative 51.4         49.0          ⋯  20
# 5 Friendly and Conventional Friendly 45.3         47.5          ⋯  33
#   baseball soccer hockey has_nba has_nfl has_mlb has_mls has_nhl has_any
# 1 58       46      7     No      No      No      No      No      No
# 2 37       61     12     Yes     Yes     Yes     No      Yes     Yes
# 3 89       41      4     No      No      No      No      No      No
# 4 33       83      8     Yes     No      Yes     Yes     Yes     Yes
# 5 31       71     22     Yes     Yes     Yes     Yes     Yes     Yes

# %%
colnames(df)
# Out:
#  [1] "state"                   "state_code"
#  [3] "population"              "sq_miles"
#  [5] "pop_density"             "region"
#  [7] "psych_region"            "psy_reg"
#  [9] "extraversion"            "agreeableness"
# [11] "conscientiousness"       "neuroticism"
# [13] "openness"                "data_science"
# [15] "artificial_intelligence" "machine_learning"
# [17] "data_analysis"           "business_intelligence"
# [19] "spreadsheet"             "statistics"
# [21] "art"                     "dance"
# [23] "museum"                  "basketball"
# [25] "football"                "baseball"
# [27] "soccer"                  "hockey"
# [29] "has_nba"                 "has_nfl"
# [31] "has_mlb"                 "has_mls"
# [33] "has_nhl"                 "has_any"

# %%
list(df$data_science)
# Out:
# [[1]]
#  [1] 20 26 25 57 37 38 36 28 34 22 46 30 25 24 19 18 20 51 74 32 35 20 26 22 22
# [26] 19 30 56 20 67 39 17 25 22 28 37 44 19 24 22 37 30 31 55 51 17 24 17

# %%
hist(df$data_science,
  breaks = 7,  # Suggest number of breaks
  main   = "Histogram of Searches for \"Data Science\"",
  sub    = "(Source: state_trends.csv)",
  ylab   = "Frequency",
  xlab   = "Searches for \"Data Science\"",
  border = NA,  # No borders on bars
  col    = "#CD0000"  # Sets fill color to red3
)
# Out:
# Plot with title “Histogram of Searches for "Data Science"”

# %%
plot(density(df$data_science))
# Out:
# Plot with title “density(x = df$data_science)”

# %%
plot(density(as.numeric(df$data_science)), main="Density Plot", sub="(Source: state_trends.csv)", ylab="Frequency", xlab="Searches for \"Data Science\"")
# Out:
# Plot with title “Density Plot”

# %%
plot(density(as.numeric(df$data_science)), main = "Density Plot", xlab = "Searches for \"Data Science\"", ylab = "Frequency"); polygon(density(as.numeric(df$data_science)), col = "#CD0000")
# Out:
# Plot with title “Density Plot”

# %%
df<-read_csv("/content/state_trends.csv") |> mutate(across(where(is_character),as_factor)) |> print()
# Out:
# Rows: 48 Columns: 34
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (11): state, state_code, region, psych_region, psy_reg, has_nba, has_nfl...
# dbl (23): population, sq_miles, pop_density, extraversion, agreeableness, co...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 48 × 34
#    state  state_code population sq_miles pop_density region psych_region psy_reg
#    <fct>  <fct>           <dbl>    <dbl>       <dbl> <fct>  <fct>        <fct>
#  1 Alaba… AL            5024279    52420          96 South  Friendly an… Friend…
#  2 Arizo… AZ            7151502   113990          63 West   Relaxed and… Creati…
#  3 Arkan… AR            3011524    53179          57 South  Friendly an… Friend…
#  4 Calif… CA           39538223   163695         242 West   Relaxed and… Creati…
#  5 Color… CO            5773714   104094          55 West   Friendly an… Friend…
#  6 Conne… CT            3605944     5543         650 North… Temperament… Uninhi…
#  7 Delaw… DE             989948     2489         398 South  Temperament… Uninhi…
#  8 Flori… FL           21538187    65758         328 South  Friendly an… Friend…
#  9 Georg… GA           10711908    59425         180 South  Friendly an… Friend…
# 10 Idaho  ID            1839106    83569          22 West   Relaxed and… Creati…
# # ℹ 38 more rows
# # ℹ 26 more variables: extraversion <dbl>, agreeableness <dbl>,
# #   conscientiousness <dbl>, neuroticism <dbl>, openness <dbl>,
# #   data_science <dbl>, artificial_intelligence <dbl>, machine_learning <dbl>,
# #   data_analysis <dbl>, business_intelligence <dbl>, spreadsheet <dbl>,
# #   statistics <dbl>, art <dbl>, dance <dbl>, museum <dbl>, basketball <dbl>,
# #   football <dbl>, baseball <dbl>, soccer <dbl>, hockey <dbl>, …

# %%
head(df,5)
# Out:
#   state      state_code population sq_miles pop_density region
# 1 Alabama    AL          5024279    52420    96         South
# 2 Arizona    AZ          7151502   113990    63         West
# 3 Arkansas   AR          3011524    53179    57         South
# 4 California CA         39538223   163695   242         West
# 5 Colorado   CO          5773714   104094    55         West
#   psych_region              psy_reg  extraversion agreeableness ⋯ football
# 1 Friendly and Conventional Friendly 55.5         52.7          ⋯ 100
# 2 Relaxed and Creative      Creative 50.6         46.6          ⋯  33
# 3 Friendly and Conventional Friendly 49.9         52.7          ⋯  52
# 4 Relaxed and Creative      Creative 51.4         49.0          ⋯  20
# 5 Friendly and Conventional Friendly 45.3         47.5          ⋯  33
#   baseball soccer hockey has_nba has_nfl has_mlb has_mls has_nhl has_any
# 1 58       46      7     No      No      No      No      No      No
# 2 37       61     12     Yes     Yes     Yes     No      Yes     Yes
# 3 89       41      4     No      No      No      No      No      No
# 4 33       83      8     Yes     No      Yes     Yes     Yes     Yes
# 5 31       71     22     Yes     Yes     Yes     Yes     Yes     Yes

# %%
boxplot(df$dance)
# Out:
# plot without title

# %%
df|>filter(dance>90)|>select(state,dance)
# Out:
#   state dance
# 1 Utah  100

# %%
# Boxplot with options
df |>
  select(dance) |>
  boxplot(
    horizontal = T,  # Horizontal
    notch  = T,      # Confidence interval for median
    main   = "Boxplot of Searches for \"Dance\"",
    sub    = "(Source: state_trends.csv)",
    xlab   = "Searches for \"Dance\"",
    col    = "#CD0000"  # red3
  )
# Out:
# Plot with title “Boxplot of Searches for "Dance"”

# %%
df |>
  select(basketball:hockey) |>
  boxplot()
# Out:
# plot without title

# %%
df |>
  filter(hockey > 45) |>
  select(state, hockey) |>
  arrange(desc(hockey))
# Out:
#   state         hockey
# 1 Minnesota     100
# 2 North Dakota   88
# 3 Massachusetts  52
# 4 Vermont        48
# 5 New Hampshire  46

# %%
df |>
  select(has_nhl, hockey) |>
  plot()
# Out:
# plot without title

# %%
df |>
  filter(has_nhl == "No") |>
  filter(hockey > 80) |>
  select(state, hockey)
# Out:
#   state        hockey
# 1 North Dakota 88

# %%
df |>
  select(has_nhl, hockey) |>
  plot(
    horizontal = T,  # Horizontal
    notch  = T,      # Confidence interval for median
    main   = "Boxplot of Searches for \"Hockey\"",
    sub    = "(Source: state_trends.csv)",
    xlab   = "Searches for \"Hockey\"",
    ylab   = "State has NHL Hockey Team",
    col    = "#CD0000"  # red3
  )
# Out:
# Warning message in (function (z, notch = FALSE, width = NULL, varwidth = FALSE, :
# “some notches went outside hinges ('box'): maybe set notch=FALSE”
# Plot with title “Boxplot of Searches for "Hockey"”

# %%
df<-read.csv("/content/state_trends.csv") |> select(basketball:hockey)|> glimpse()
# Out:
# Rows: 48
# Columns: 5
# $ basketball <int> 55, 33, 61, 21, 31, 45, 35, 26, 35, 35, 45, 74, 88, 81, 100…
# $ football   <int> 100, 33, 52, 20, 33, 23, 34, 37, 61, 41, 30, 40, 77, 47, 47…
# $ baseball   <int> 58, 37, 89, 33, 31, 39, 37, 35, 38, 28, 41, 40, 51, 47, 39,…
# $ soccer     <int> 46, 61, 41, 83, 71, 91, 65, 70, 62, 65, 74, 65, 67, 80, 58,…
# $ hockey     <int> 7, 12, 4, 8, 22, 34, 18, 11, 6, 11, 18, 11, 14, 8, 7, 4, 36…

# %%
# Plot all associations
df |> plot()
# Out:
# plot without title

# %%
# Bivariate scatterplot with defaults
df |>
  select(soccer, hockey) |>
  plot()
# Out:
# plot without title

# %%
df |>
  select(soccer, hockey) |>
  plot(
    main = "Scatterplot of Searches by State",
    xlab = "Searches for \"Soccer\"",
    ylab = "Searches for \"Hockey\"",
    col  = "red3",  # Color of points
    pch  = 20,      # "Plotting character" (small circle)
  )
# Out:
# Plot with title “Scatterplot of Searches by State”

# %%
plot(df$soccer, df$hockey); abline(lm(df$hockey ~ df$soccer), col = "blue")
# Out:
# plot without title

# %%
plot(uspop)
# Out:
# plot without title

# %%
# Plot with options
uspop |>
  plot(
    main = "US Population 1790–1970 ",
    sub  = "(Source: datasets::uspop)",
    xlab = "Year",
    ylab = "Population (in millions)",
  )
abline(v = 1930, col = "lightgray")
text(1930, 10, "1930", col = "red3")
abline(v = 1940, col = "lightgray")
text(1940, 10, "1940", col = "red3")
# Out:
# Plot with title “US Population 1790–1970 ”

# %%
# is easier to use and is preferred.
ts.plot(uspop)
# Out:
# plot without title

# %%
# Three different plot functions
plot(EuStockMarkets)     # Stacked windows
plot.ts(EuStockMarkets)  # Identical
ts.plot(EuStockMarkets)  # One window
# Out:
# plot without title
# plot without title

# %%
# Plot with options
ts.plot(
  EuStockMarkets,
  col = rainbow(4))  # Color lines
legend(              # Add legend
  "topleft",         # Position
  legend = colnames(EuStockMarkets),  # Names for legend
  col = rainbow(4),  # Colors for legend
  lty = 1            # Line type: solid
)
# Out:
# plot without title

# %%
df <- read_csv("/content/state_trends.csv") |>
  select(state_code, artificial_intelligence:hockey)
# Out:
# Rows: 48 Columns: 34
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (11): state, state_code, region, psych_region, psy_reg, has_nba, has_nfl...
# dbl (23): population, sq_miles, pop_density, extraversion, agreeableness, co...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# Calculate clusters using hclust(), an agglomerative method
hc <- df |>  # Get data
  dist() |>  # Compute distance/dissimilarity matrix
  hclust()   # Compute hierarchical clusters
# Out:
# Warning message in dist(df):
# “NAs introduced by coercion”

# %%
# Plot dendrogram
hc |> plot(labels = df$state_code)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
plot(hc); rect.hclust(hc, k = 2, border = "gray80")
# Out:
# Plot with title “Cluster Dendrogram”

# %%
plot(hc); rect.hclust(hc, k = 3, border = 2:4)
# Out:
# Plot with title “Cluster Dendrogram”
