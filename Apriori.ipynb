# %%
install.packages("arules")
install.packages("arulesViz")
install.packages("arulesData")
install.packages("pacman")
install.packages("rio")
install.packages("tidyverse")
install.packages("dplyr")
install.packages("data.table")
install.packages("magrittr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘iterators’, ‘permute’, ‘zoo’, ‘tweenr’, ‘polyclip’, ‘RcppEigen’, ‘gridExtra’, ‘RcppArmadillo’, ‘ca’, ‘colorspace’, ‘foreach’, ‘gclus’, ‘qap’, ‘registry’, ‘TSP’, ‘vegan’, ‘lmtest’, ‘ggforce’, ‘ggrepel’, ‘viridis’, ‘tidygraph’, ‘graphlayouts’, ‘crosstalk’, ‘lazyeval’, ‘seriation’, ‘vcd’, ‘igraph’, ‘scatterplot3d’, ‘ggraph’, ‘DT’, ‘plotly’, ‘visNetwork’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘arulesData’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’, ‘writexl’, ‘R.utils’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(arules)
library(magrittr)

# %%
data("Groceries")

# %%
df<-Groceries

# %%
rules<-df%>%apriori(parameter = list(supp = 0.01, conf = 0.5))
rules
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.5    0.1    1 none FALSE            TRUE       5    0.01      1
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 98
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[169 item(s), 9835 transaction(s)] done [0.01s].
# sorting and recoding items ... [88 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [15 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
# set of 15 rules

# %%
options(digits = 2)
inspect(rules[1:15])
# Out:
#      lhs                                       rhs                support
# [1]  {curd, yogurt}                         => {whole milk}       0.010
# [2]  {other vegetables, butter}             => {whole milk}       0.011
# [3]  {other vegetables, domestic eggs}      => {whole milk}       0.012
# [4]  {yogurt, whipped/sour cream}           => {whole milk}       0.011
# [5]  {other vegetables, whipped/sour cream} => {whole milk}       0.015
# [6]  {pip fruit, other vegetables}          => {whole milk}       0.014
# [7]  {citrus fruit, root vegetables}        => {other vegetables} 0.010
# [8]  {tropical fruit, root vegetables}      => {other vegetables} 0.012
# [9]  {tropical fruit, root vegetables}      => {whole milk}       0.012
# [10] {tropical fruit, yogurt}               => {whole milk}       0.015
# [11] {root vegetables, yogurt}              => {other vegetables} 0.013
# [12] {root vegetables, yogurt}              => {whole milk}       0.015
# [13] {root vegetables, rolls/buns}          => {other vegetables} 0.012
# [14] {root vegetables, rolls/buns}          => {whole milk}       0.013
# [15] {other vegetables, yogurt}             => {whole milk}       0.022
#      confidence coverage lift count
# [1]  0.58       0.017    2.3   99
# [2]  0.57       0.020    2.2  113
# [3]  0.55       0.022    2.2  121
# [4]  0.52       0.021    2.1  107
# [5]  0.51       0.029    2.0  144
# [6]  0.52       0.026    2.0  133
# [7]  0.59       0.018    3.0  102
# [8]  0.58       0.021    3.0  121
# [9]  0.57       0.021    2.2  118
# [10] 0.52       0.029    2.0  149
# [11] 0.50       0.026    2.6  127
# [12] 0.56       0.026    2.2  143
# [13] 0.50       0.024    2.6  120
# [14] 0.52       0.024    2.0  125
# [15] 0.51       0.043    2.0  219

# %%
library(arulesViz)

# %%
# Graph of top 15 rules
plot(rules[1:15], method = "graph",control = list(type = "items"))
# Out:
# Warning message:
# “Unknown control parameters: type”
# Available control parameters (with default values):
# layout	 =  stress
# circular	 =  FALSE
# ggraphdots	 =  NULL
# edges	 =  <environment>
# nodes	 =  <environment>
# nodetext	 =  <environment>
# colors	 =  c("#EE0000FF", "#EEEEEEFF")
# engine	 =  ggplot2
# max	 =  100
# verbose	 =  FALSE
# plot without title
